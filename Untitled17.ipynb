# %% [markdown]
# <a href="https://colab.research.google.com/github/jangidN/Machine-learning/blob/master/Untitled17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tweepy

# %%
import matplotlib.pyplot as plt
import time
import textblob

# %%
consumer_key='o69r3NU2sQIc5k6KRFmA3DjGr'
consumer_sec='X6KFJEJthuwzHI4ahRdqBEPOcnCl4qO0QGGp2QoVybV8acVoab'
access_token='974243592100196352-9PvW5ADR9P3fSESt7muEXuHMRZFIUa0'
access_sec='IVqnWFLt6Mp2JMlJw4CqRMZGpXeNoOTvDoTXmydz5qDES'

# %%
auth=tweepy.OAuthHandler(consumer_key,consumer_sec)

# %%
auth.set_access_token(access_token,access_sec)

# %%
api_connect=tweepy.API(auth)

# %%
tweet_data=api_connect.search('modi',count=10)

# %%
pos=0
neg=0
neu=0
for tweet in tweet_data:
  analysis=textblob
# Out:
# Status(_api=<tweepy.api.API object at 0x7fae6a9ec828>, _json={'created_at': 'Fri Jul 05 08:36:02 +0000 2019', 'id': 1147061563808997376, 'id_str': '1147061563808997376', 'text': "@shaziailmi Ma'am clear my doubt please , at these fake posts being spread on SM or are they real, because here I f… https://t.co/Z7vowpl9WB", 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'shaziailmi', 'name': 'Shazia Ilmi', 'id': 47055387, 'id_str': '47055387', 'indices': [0, 11]}], 'urls': [{'url': 'https://t.co/Z7vowpl9WB', 'expanded_url': 'https://twitter.com/i/web/status/1147061563808997376', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1146606492906246144, 'in_reply_to_status_id_str': '1146606492906246144', 'in_reply_to_user_id': 47055387,
# ...
